# %% [markdown]
# <a href="https://colab.research.google.com/github/naylaislakhulzahra2025-hash/KKA-X-Semester-1/blob/main/2_Tipe_Variabel_Nayla_Islakhul_ZahraX_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Nayla Islakhul Zahra
#
# Kelas:X.11
#
# No.absen:23

# %% [markdown]
# Konsep Dasae Variabel

# %%
print("naylaislakhulzahraa.2025@gmail.com")
print("naylaislakhulzahraa.2025@gmail.com")
print("naylaislakhulzahraa.2025@gmail.com")
# Out:
# naylaislakhulzahraa.2025@gmail.com
# naylaislakhulzahraa.2025@gmail.com
# naylaislakhulzahraa.2025@gmail.com

# %%
email_user_1 = "naylaislakhulzahraa.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print(email_user_1)
# Out:
# naylaislakhulzahraa.2025@gmail.com
# naylaislakhulzahraa.2025@gmail.com
# naylaislakhulzahraa.2025@gmail.com

# %% [markdown]
# Peraturan Penamaan Variabel

# %%
#Hanya diperbolehkan menggunakan hutuf,angka dan underscore
email user 2= "bobbyaliando@gmail.com"

print(email user 2)
# Out:
#   File "/tmp/ipython-input-1468171255.py", line 2
#     email user 2= "bobbyaliando@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 = "bobbyaliando@gmail.com"

print(emailuser2)
# Out:
# bobbyaliando@gmail.com

# %%
#Tidak boleh didahului oleh angka
3_email_user = "willytaulany@gamil.com"

print(3_email_user)
# Out:
#   File "/tmp/ipython-input-47283286.py", line 2
#     3_email_user = "willytaulany@gamil.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 = "willytaulani@gmail.com"

print(email_user_3)
# Out:
# willytaulani@gmail.com

# %%
#Tidak boleh menggunakan kata kunci phyton
for = "HimamHimawan@gamil.com"

print(for)
# Out:
#   File "/tmp/ipython-input-3634774038.py", line 2
#     for = "HimamHimawan@gamil.com"
#         ^
# SyntaxError: invalid syntax

# %%
For = "HimamHimawan@Gmail.com"

print(for)
# Out:
#   File "/tmp/ipython-input-2111266407.py", line 3
#     print(for)
#           ^
# SyntaxError: invalid syntax

# %%
print = "juliawati@gmail.com"

print(for)
# Out:
#   File "/tmp/ipython-input-2614581988.py", line 3
#     print(for)
#           ^
# SyntaxError: invalid syntax

# %%
print = "Juliawati@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1948412904.py in <cell line: 0>()
#       1 print = "Juliawati@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
#tidak error tapi dianjurkan harus deskriptif
_ = "Devandraarnoldi@gmail.com"

# %%
print(_)
# Out:
# Devandraarnoldi@gmail.com

# %%
_ = "haidarhalilintar.gmail.com"

# %%
print(_)
# Out:
# haidarhalilintar.gmail.com

# %% [markdown]
# Assignment

# %%
#Single assignment
nama_mahasiswa_1 ="Alexandrio"

print(nama_mahasiswa_1)
# Out:
# Alexandrio

# %%
#Multiple assigment

# nama_barang_1= "rinso"
# nama_barang_2= " molto"

nama_barang_1, nama_barang_2 = "rinso", "molto"

print(nama_barang_1)
print(nama_barang_2)
# Out:
# rinso
# molto

# %%
#Assigment yang sama
nilai_devandra= nilai_willy = nilai_dzakki = 100

print(nilai_devandra)
print(nilai_willy)
print(nilai_dzakki)
# Out:
# 100
# 100
# 100

# %%
#Menimpa/mengubah Nilai variabel

nilai_himam=95

# %%
print(nilai_himam)
# Out:
# 95

# %%
nilai_himam = 100

# %%
print(nilai_himam)
# Out:
# 100

# %% [markdown]
# Penggunaan Operator di phython

# %%
#Tanpa variabel
print(20+3)
# Out:
# 23

# %%
#Operand disimpan ke dalam variabel
roti_swiss_alex=20
roti_swiss_nazril=3

print(roti_swiss_alex + roti_swiss_nazril)
# Out:
# 23

# %%
#Hasil operasi disimpan ke dalam variabel
jumlah_roti_swiss=20+3

print(jumlah_roti_swiss)
# Out:
# 23

# %%
#Operand dan hasil operasi disimpan ke variabel
roti_swiss_alex = 20
roti_swiss_nazril = 3

jumlah_roti_swiss = roti_swiss_alex + roti_swiss_nazril

print(jumlah_roti_swiss)
# Out:
# 23

# %% [markdown]
# Operator Aritmatika

# %% [markdown]
# Tipe Variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 72.5

type(berat_badan)
# Out:
# float

# %%
nama = "Dzakki"

type(nama)
# Out:
# str

# %%
lulus = True

type(lulus)
# Out:
# bool

# %%
titik_koordinat = -5
type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang = -10.0
type(titik_koordinat_bintang)
# Out:
# float

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)
print(usia)
type(usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5
print(berat_badan)
type(berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan = int(berat_badan)
print(berat_badan)
type(berat_badan)
# Out:
# 72
# int

# %%
usia = 7
print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1
print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus= bool(lulus)
print(lulus)
type(lulus)
# Out:
# True
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# 0
# int

# %%
lulus= bool(lulus)
print(lulus)
type(lulus)
# Out:
# False
# bool
