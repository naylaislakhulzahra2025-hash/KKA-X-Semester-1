# %% [markdown]
# <a href="https://colab.research.google.com/github/naylaislakhulzahra2025-hash/KKA-X-Semester-1/blob/main/%221_Fungsi_print_nayla_islakhul_zahra_X_11_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:Nayla Islakhul Z
#
# Kelas:X.11
#
# No.absen:23

# %% [markdown]
# #Menampilkan Teks bebas

# %%
print("Nayla Islakhul Zahra")
# Out:
# Nayla Islakhul Zahra

# %% [markdown]
# #Menampilkan Nilai Variabel

# %%
nama_saudara = "Aditya Rifqi Hamizan"

print(nama_saudara)
# Out:
# Aditya Rifqi Hamizan

# %%
jumlah_saudara= 1
print(jumlah_saudara)
# Out:
# 1

# %% [markdown]
# ##Menampilkan Teks Bebas dan Nilai Variabel

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda Koma

# %%
print("saya memiliki saudara sebanyak {jumlah_saudara}. Nama saudara saya adalah {nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak {jumlah_saudara}. Nama saudara saya adalah {nama_saudara}.

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda Plus

# %%
print("saya memiliki saudara sebanyak " + str('jumlah_saudara') + ". " + "Nama saudara saya adalah " + 'nama_saudara' + ".")
# Out:
# saya memiliki saudara sebanyak jumlah_saudara. Nama saudara saya adalah nama_saudara.

# %% [markdown]
# #menampilkan teks bebas dan nilai variabel menggunakan f string

# %%
print(f"saya memiliki saudara sebanyak,{'jumlah_saudara'}. Nama saudara saya adalah{'nama_saudara'}.")
# Out:
# saya memiliki saudara sebanyak,jumlah_saudara. Nama saudara saya adalahnama_saudara.

# %% [markdown]
# #Escape Character

# %%
print("Nama: Nayla Islakhul Z")
print("Kelas: x.11")
print("No.Absen: 23")
# Out:
# Nama: Nayla Islakhul Z
# Kelas: x.11
# No.Absen: 23

# %%
print("Nama: Nayla Islakhul Z\nKelas: x.11\nNo.Absen :23")
# Out:
# Nama: Nayla Islakhul Z
# Kelas: x.11
# No.Absen :23

# %%
print("""Nama\t\t: Nayla Islakhul Z
Kelas\t\t: x.11
No.Absen\t: 23""")
# Out:
# Nama		: Nayla Islakhul Z
# Kelas		: x.11
# No.Absen	: 23

# %%
print("Nayla Islakhul Zahra")
# Out:
# Nayla Islakhul Zahra

# %%
print('Nayla Islakhul Zahra')
# Out:
# Nayla Islakhul Zahra

# %%
print('Habib Ja\'far')
# Out:
# Habib Ja'far

# %%
print("Habib Ja'far")
# Out:
# Habib Ja'far

# %%
print('Bu Shinta berkata, "Harap fokus menyimak!".')
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print("Bu Shinta berkata, \"Harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# #Fungsi paramenter

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
print('nama_siswa_1')
print('nama_siswa_2')
# Out:
# nama_siswa_1
# nama_siswa_2

# %%
# Latihan
# Silakan tampilkan keluaran/output berupa:
# Haidar*Adzka*Daffanes*Adzka

# %%
print("nama_siswa_1")
# Out:
# nama_siswa_1

# %%
print("Nama_Siswa_1")
# Out:
# Nama_Siswa_1

# %%
print("nama_siswa_2")
# Out:
# nama_siswa_2

# %%
print(nama_siswa_2)
# Out:
# Adzka

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_1,nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1,nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1, end="-")
print(nama_siswa_2)
# Out:
# Daffanes-Adzka
