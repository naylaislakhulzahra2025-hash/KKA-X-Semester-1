# %% [markdown]
# <a href="https://colab.research.google.com/github/naylaislakhulzahra2025-hash/KKA-X-Semester-1/blob/main/3_Aplikasi_Sederhana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Nama:Nayla Islakhul Zahra

Kelas:X.11

No.absen:23

# %% [markdown]
# Aplikasi Sederhana Menghitung Volume Bola

# %%
jari_jari = int(input("Masukkan jari-jari dari bola (cm): "))
pi = 22/7
volume_bola = 4/3 * pi * jari_jari**3
print(f"volume bola adalah {volume_bola} cm^3. ")
# Out:
# Masukkan jari-jari dari bola (cm): 7
# volume bola adalah 1437.333333333333 cm^3.

# %% [markdown]
# Nama:Nayla Islakhul Zahra
#
# Kelas:x.11
#
# No.absen:23
#
# Nama kelompok:kelinci imut

# %% [markdown]
# Aplikasi Sederhana Menghitung Volume Kerucut

# %%
jari_jari = int(input("Masukkan jari-jari dari kerucut (dm): "))
tinggi= int(input("Masukkan tinggi dari kerucut (dm): "))
pi = 3.14
volume_kerucut = 1/3 * pi * jari_jari ** 2 * tinggi
print(f"volume kerucut adalah {volume_kerucut} dm^2. ")
# Out:
# Masukkan jari-jari dari kerucut (dm): 3
# Masukkan tinggi dari kerucut (dm): 5
# volume kerucut adalah 47.1 dm^2.
